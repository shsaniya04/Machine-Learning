# %%
import pandas as pd

df = pd.read_csv("bank-full.csv", sep=";")

print(df.shape)
print(df.head())
# Out:
# (45211, 1)
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...
# 1  44;"technician";"single";"secondary";"no";29;"...
# 2  33;"entrepreneur";"married";"secondary";"no";2...
# 3  47;"blue-collar";"married";"unknown";"no";1506...
# 4  33;"unknown";"single";"unknown";"no";1;"no";"n...

# %%
df = pd.read_csv("bank-full.csv", sep=";")

print(df.shape)
print(df.columns.tolist())
# Out:
# (45211, 1)
# ['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"']

# %%
import os

print(os.path.abspath("bank-full.csv"))
# Out:
# C:\Users\hp\Desktop\Machine Learning\bank-full.csv

# %%
file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

with open(file_path, "r", encoding="utf-8") as f:
    first_line = f.readline()

print(repr(first_line))
# Out:
# '\ufeff"age;""job"";""marital"";""education"";""default"";""balance"";""housing"";""loan"";""contact"";""day"";""month"";""duration"";""campaign"";""pdays"";""previous"";""poutcome"";""y"""\n'

# %%
import pandas as pd

df = pd.read_csv(
    file_path,
    sep=";",
    quotechar='"',
    engine="python"
)

print(df.shape)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\python_parser.py:989, in PythonParser._next_iter_line(self, row_num)
#     988 assert not isinstance(self.data, list)
# --> 989 line = next(self.data)
#     990 # lie about list[str] vs list[Scalar] to minimize ignores
#
# Error: ';' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(
#       4     file_path,
#       5     sep=";",
#       6     quotechar='"',
#       7     engine="python"
#       8 )
#      10 print(df.shape)
#      11 print(df.head())
#
# ...

# %%
import pandas as pd

file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

df = pd.read_csv(file_path, sep=";")

print(df.shape)
print(df.head())
# Out:
# (45211, 1)
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...
# 1  44;"technician";"single";"secondary";"no";29;"...
# 2  33;"entrepreneur";"married";"secondary";"no";2...
# 3  47;"blue-collar";"married";"unknown";"no";1506...
# 4  33;"unknown";"single";"unknown";"no";1;"no";"n...

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (45211, 1)
# ['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"']

# %%
file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

with open(file_path, "rb") as f:
    data = f.read(500)

print(data)
# Out:
# b'\xef\xbb\xbf"age;""job"";""marital"";""education"";""default"";""balance"";""housing"";""loan"";""contact"";""day"";""month"";""duration"";""campaign"";""pdays"";""previous"";""poutcome"";""y"""\r\n"58;""management"";""married"";""tertiary"";""no"";2143;""yes"";""no"";""unknown"";5;""may"";261;1;-1;0;""unknown"";""no"""\r\n"44;""technician"";""single"";""secondary"";""no"";29;""yes"";""no"";""unknown"";5;""may"";151;1;-1;0;""unknown"";""no"""\r\n"33;""entrepreneur"";""married"";""secondary"";""no"";2;""yes"";"'

# %%
print(data[:200].decode("utf-8", errors="replace"))
# Out:
# ﻿"age;""job"";""marital"";""education"";""default"";""balance"";""housing"";""loan"";""contact"";""day"";""month"";""duration"";""campaign"";""pdays"";""previous"";""poutcome"";""y"""
# "58;""managem

# %%
import csv

file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

with open(file_path, "r", encoding="utf-8", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    
    header = next(reader)
    first_row = next(reader)

print("Header:", header)
print("Number of columns:", len(header))
print("First row:", first_row)
print("Number of values:", len(first_row))
# Out:
# Header: ['\ufeff"age', 'job""', 'marital""', 'education""', 'default""', 'balance""', 'housing""', 'loan""', 'contact""', 'day""', 'month""', 'duration""', 'campaign""', 'pdays""', 'previous""', 'poutcome""', 'y"""']
# Number of columns: 17
# First row: ['58;"management";"married";"tertiary";"no";2143;"yes";"no";"unknown";5;"may";261;1;-1;0;"unknown";"no"']
# Number of values: 1

# %%
import csv
import pandas as pd

file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

with open(file_path, "r", encoding="utf-8", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    rows = list(reader)

df = pd.DataFrame(rows[1:], columns=rows[0])

print(df.shape)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:911, in _finalize_columns_and_data(content, columns, dtype)
#     910 try:
# --> 911     columns = _validate_or_indexify_columns(contents, columns)
#     912 except AssertionError as err:
#     913     # GH#26429 do not raise user-facing AssertionError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:958, in _validate_or_indexify_columns(content, columns)
#     956 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     957     # caller's responsibility to check for this...
# --> 958     raise AssertionError(
#     959         f"{len(columns)} columns passed, passed data had {len(content)} columns"
#     960     )
#     961 if is_mi_list:
# ...

# %%
import csv

file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

with open(file_path, "r", encoding="utf-8") as f:
    reader = csv.reader(f, delimiter=";")

    header = next(reader)
    first_row = next(reader)

print("HEADER:")
print(header)
print("\nHEADER LENGTH:", len(header))

print("\nFIRST ROW:")
print(first_row)
print("\nFIRST ROW LENGTH:", len(first_row))
# Out:
# HEADER:
# ['\ufeff"age', 'job""', 'marital""', 'education""', 'default""', 'balance""', 'housing""', 'loan""', 'contact""', 'day""', 'month""', 'duration""', 'campaign""', 'pdays""', 'previous""', 'poutcome""', 'y"""']
#
# HEADER LENGTH: 17
#
# FIRST ROW:
# ['58;"management";"married";"tertiary";"no";2143;"yes";"no";"unknown";5;"may";261;1;-1;0;"unknown";"no"']
#
# FIRST ROW LENGTH: 1

# %%
import pandas as pd

file_path = r"C:\Users\hp\Desktop\Machine Learning\bank-full.csv"

# Read raw lines
with open(file_path, "r", encoding="utf-8-sig") as f:
    lines = f.readlines()

# Split each line using ;
data = [line.strip().split(";") for line in lines]

# Create DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

print(df.shape)
print(df.head())
# Out:
# (45211, 17)
#   "age           ""job""  ""marital""  ""education"" ""default"" ""balance""  \
# 0  "58    ""management""  ""married""   ""tertiary""      ""no""        2143
# 1  "44    ""technician""   ""single""  ""secondary""      ""no""          29
# 2  "33  ""entrepreneur""  ""married""  ""secondary""      ""no""           2
# 3  "47   ""blue-collar""  ""married""    ""unknown""      ""no""        1506
# 4  "33       ""unknown""   ""single""    ""unknown""      ""no""           1
#
#   ""housing"" ""loan""  ""contact"" ""day"" ""month"" ""duration""  \
# 0     ""yes""   ""no""  ""unknown""       5   ""may""          261
# 1     ""yes""   ""no""  ""unknown""       5   ""may""          151
# 2     ""yes""  ""yes""  ""unknown""       5   ""may""           76
# 3     ""yes""   ""no""  ""unknown""       5   ""may""           92
# 4      ""no""   ""no""  ""unknown""       5   ""may""          198
#
#   ""campaign"" ""pdays"" ""previous"" ""poutcome""   ""y"""
# ...

# %%
# Remove all double quotes from every string value
df = df.map(
    lambda x: x.replace('"', '').strip()
    if isinstance(x, str)
    else x
)

print(df.head())
# Out:
#   "age       ""job"" ""marital"" ""education"" ""default"" ""balance""  \
# 0   58    management     married      tertiary          no        2143
# 1   44    technician      single     secondary          no          29
# 2   33  entrepreneur     married     secondary          no           2
# 3   47   blue-collar     married       unknown          no        1506
# 4   33       unknown      single       unknown          no           1
#
#   ""housing"" ""loan"" ""contact"" ""day"" ""month"" ""duration""  \
# 0         yes       no     unknown       5       may          261
# 1         yes       no     unknown       5       may          151
# 2         yes      yes     unknown       5       may           76
# 3         yes       no     unknown       5       may           92
# 4          no       no     unknown       5       may          198
#
#   ""campaign"" ""pdays"" ""previous"" ""poutcome"" ""y"""
# 0            1        -1            0      unknown     no
# ...

# %%
df.columns = (
    df.columns
    .str.replace('"', '', regex=False)
    .str.strip()
)

print(df.columns.tolist())
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']

# %%
print(df.dtypes)
# Out:
# age          str
# job          str
# marital      str
# education    str
# default      str
# balance      str
# housing      str
# loan         str
# contact      str
# day          str
# month        str
# duration     str
# campaign     str
# pdays        str
# previous     str
# poutcome     str
# y            str
# dtype: object

# %%
numeric_cols = [
    'age',
    'balance',
    'day',
    'duration',
    'campaign',
    'pdays',
    'previous'
]

df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# age          int64
# job            str
# marital        str
# education      str
# default        str
# balance      int64
# housing        str
# loan           str
# contact        str
# day          int64
# month          str
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# poutcome       str
# y              str
# dtype: object

# %%
print("Shape:", df.shape)
print("Duplicates:", df.duplicated().sum())
print("\nMissing values:")
print(df.isnull().sum())
print("\nTarget distribution:")
print(df['y'].value_counts())
# Out:
# Shape: (45211, 17)
# Duplicates: 0
#
# Missing values:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#
# Target distribution:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
df.to_csv(
    r"C:\Users\hp\Desktop\Machine Learning\bank-full-cleaned.csv",
    index=False
)
